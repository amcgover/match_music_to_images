# %%
"""
Copyright 2021 Aonghus McGovern

This file is part of Music_Image_Matcher_Notebooks_And_Writeup.

Music_Image_Matcher_Notebooks_And_Writeup is free software: you can redistribute it and/or modify it under the terms of the 
GNU General Public License as published by the Free Software Foundation, either version 3 of the License, or (at your option) 
any later version.

Music_Image_Matcher_Notebooks_And_Writeup is distributed in the hope that it will be useful, but WITHOUT ANY WARRANTY; 
without even the implied warranty of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the GNU General Public License 
for more details.

You should have received a copy of the GNU General Public License along with Music_Image_Matcher_Notebooks_And_Writeup.  
If not, see <https://www.gnu.org/licenses/>.
"""

# %%
import os
import pandas as pd
import requests

image_folder = 'Images/'

image_pattern = 'http://artwork-cdn.7static.com/static/img/sleeveart/(.+)'

# %%
# Load the Oramas Data
input_file = pd.read_csv('oramas_data_with_names.csv')

# %%
input_file.columns.values
# Out:
# array(['msd_track_id', 'genre', 'album_index', 'set', 'msd_artist_id',
#        'image_url', 'song_name', 'artist_name', 'album_name'],
#       dtype=object)

# %%
# Create a loop that downloads the corresponding image for each row of the Oramas data, where available
count = 0

# Create a variable to store the name to use to save the file. This name corresponds to the index
# of the Oramas data
filename = 0

# NOTE: After 900+ requests a request will time out, causing the cell to terminate. If this happens just execute 
# the cell again.

for _,row in input_file.iterrows():
    # If the image file already exists, skip this record
    if os.path.exists(image_folder+str(filename) + '.jpg'):
        filename += 1
        print('skipping, filename', filename)
        continue
    # Make a request for the image at the path
    r = requests.get(row['image_url'])
    # If the request was successful, write the image
    if r.status_code == 200:
        open(image_folder+str(filename) + '.jpg', 'wb').write(r.content)
        filename += 1
    # If the request wasn't successful, print the filename and exit
    else:
        print(f)
        print(r.text)
        
        sys.exit()
    
    # Maintain a count to keep track of progress
    count += 1
    
    if count % 100 == 0:
        print(count)
# Out:
# skipping, filename 1
# skipping, filename 2
# skipping, filename 3
# skipping, filename 4
# skipping, filename 5
# skipping, filename 6
# skipping, filename 7
# skipping, filename 8
# skipping, filename 9
# skipping, filename 10
# skipping, filename 11
# skipping, filename 12
# skipping, filename 13
# skipping, filename 14
# skipping, filename 15
# skipping, filename 16
# skipping, filename 17
# skipping, filename 18
# skipping, filename 19
# skipping, filename 20
# skipping, filename 21
# skipping, filename 22
# skipping, filename 23
# skipping, filename 24
# skipping, filename 25
# skipping, filename 26
# skipping, filename 27
# skipping, filename 28
# skipping, filename 29
# skipping, filename 30
# skipping, filename 31
# skipping, filename 32
# skipping, filename 33
# skipping, filename 34
# skipping, filename 35
# skipping, filename 36
# skipping, filename 37
# skipping, filename 38
# skipping, filename 39
# skipping, filename 40
# skipping, filename 41
# skipping, filename 42
# ...
